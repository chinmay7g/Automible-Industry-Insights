# %%
#importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#reading the data
data = pd.read_csv(r'C:\Users\Administrator\Desktop\Python Test Data\NPTEL\Toyota.csv', index_col=0, na_values= ['??','????'])

# %%
data.head(5)
# Out:
#    Price   Age       KM FuelType    HP  MetColor  Automatic    CC  Doors  \
# 0  13500  23.0  46986.0   Diesel  90.0       1.0          0  2000  three
# 1  13750  23.0  72937.0   Diesel  90.0       1.0          0  2000      3
# 2  13950  24.0  41711.0   Diesel  90.0       NaN          0  2000      3
# 3  14950  26.0  48000.0   Diesel  90.0       0.0          0  2000      3
# 4  13750  30.0  38500.0   Diesel  90.0       0.0          0  2000      3
#
#    Weight
# 0    1165
# 1    1165
# 2    1165
# 3    1165
# 4    1170

# %%
data.dropna(axis= 0, inplace= True)
data.head(10)
# Out:
#     Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0   13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1   13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 3   14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4   13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# 5   12950  32.0  61000.0   Diesel   90.0       0.0          0  2000      3
# 8   21500  27.0  19700.0   Petrol  192.0       0.0          0  1800      3
# 10  20950  25.0  31461.0   Petrol  192.0       0.0          0  1800      3
# 11  19950  22.0  43610.0   Petrol  192.0       0.0          0  1800      3
# 12  19600  25.0  32189.0   Petrol  192.0       0.0          0  1800      3
# 13  21500  31.0  23000.0   Petrol  192.0       1.0          0  1800      3
#
#     Weight
# 0     1165
# 1     1165
# 3     1165
# 4     1170
# 5     1170
# 8     1185
# 10    1185
# 11    1185
# 12    1185
# 13    1185

# %%
sns.set(style= 'darkgrid')
sns.regplot(x= 'Age', y= 'Price', data= data)

# %%
plt.scatter(data['Age'], data['Price'], c= 'red')

# %%
#utilising one more variable and sorting Price vs Age by FuelType

sns.lmplot(x= 'Age', y= 'Price', data= data, fit_reg= False, hue= 'Automatic', legend= True, palette= 'Set1')
